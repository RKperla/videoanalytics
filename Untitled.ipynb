# %%
import pandas as pd
df = pd.read_csv('../processed_data/list_landmarks.csv')

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'cloth_type', u'img_name', u'lm_vis1', u'lm_vis2',
#        u'lm_vis3', u'lm_vis4', u'lm_vis5', u'lm_vis6', u'lm_vis7', u'lm_vis8',
#        u'x1', u'x2', u'x3', u'x4', u'x5', u'x6', u'x7', u'x8', u'y1', u'y2',
#        u'y3', u'y4', u'y5', u'y6', u'y7', u'y8'],
#       dtype='object')

# %%
df2 = df[df['cloth_type'] == 1]
df2
# Out:
#         Unnamed: 0  cloth_type  \
# 0                0           1
# 1                1           1
# 2                2           1
# 3                3           1
# 4                4           1
# 5                5           1
# 6                6           1
# 7                7           1
# 8                8           1
# 9                9           1
# 10              10           1
# 11              11           1
# 12              12           1
# 13              13           1
# 14              14           1
# 15              15           1
# 16              16           1
# 17              17           1
# 18              18           1
# 19              19           1
# 20              20           1
# 21              21           1
# 22              22           1
# 23              23           1
# 24              24           1
# 25              25           1
# 26              26           1
# 27              27           1
# 28              28           1
# ...

# %%
df1 = pd.read_csv('../processed_data/list_att_img.csv')

# %%
df1.head()
# Out:
#                                               name                  atts
# 0  img/Sheer_Pleated-Front_Blouse/img_00000001.jpg            [717, 818]
# 1  img/Sheer_Pleated-Front_Blouse/img_00000002.jpg            [717, 818]
# 2  img/Sheer_Pleated-Front_Blouse/img_00000003.jpg  [141, 717, 837, 956]
# 3  img/Sheer_Pleated-Front_Blouse/img_00000004.jpg                 [716]
# 4  img/Sheer_Pleated-Front_Blouse/img_00000005.jpg  [349, 405, 717, 810]

# %%
df2 = pd.read_csv('../processed_data/list_bbox.csv')
df2.head()
# Out:
#    Unnamed: 0                                         img_name  x1  y1   x2  \
# 0           0  img/Sheer_Pleated-Front_Blouse/img_00000001.jpg  72  79  232
# 1           1  img/Sheer_Pleated-Front_Blouse/img_00000002.jpg  67  59  155
# 2           2  img/Sheer_Pleated-Front_Blouse/img_00000003.jpg  65  65  156
# 3           3  img/Sheer_Pleated-Front_Blouse/img_00000004.jpg  51  62  167
# 4           4  img/Sheer_Pleated-Front_Blouse/img_00000005.jpg  46  88  166
#
#     y2
# 0  273
# 1  161
# 2  200
# 3  182
# 4  262
